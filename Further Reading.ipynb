# %% [markdown]
# # Pandas

# %%
import pandas as pd
py_list = [3, 8, 14, 25, 11]
series = pd.Series(py_list)
series
# Out:
# 0     3
# 1     8
# 2    14
# 3    25
# 4    11
# dtype: int64

# %%
indices = ['a', 'b', 'c', 'd', 'e']
series = pd.Series(py_list, index=indices)
series
# Out:
# a     3
# b     8
# c    14
# d    25
# e    11
# dtype: int64

# %%
data = {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
        'Age': [25, 30, 35, 40, 45]}
df = pd.DataFrame(data)
df
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
# 3    David   40
# 4      Eve   45

# %%
df.sort_values(by='Age', ascending=False)
# Out:
#       Name  Age
# 4      Eve   45
# 3    David   40
# 2  Charlie   35
# 1      Bob   30
# 0    Alice   25

# %%
GDP = pd.read_csv('./Gross Domestic Product.csv', skiprows=7)
GDP.head()
# Out:
#   Important notes  Unnamed: 1
# 0            1948      455134
# 1            1949      470210
# 2            1950      485925
# 3            1951      503980
# 4            1952      511536

# %%
GDP.shape
# Out:
# (362, 2)

# %%
GDP.columns[:3]
# Out:
# Index(['Important notes', 'Unnamed: 1'], dtype='object')

# %% [markdown]
# # Scikit-learn

# %%
from sklearn.datasets import load_diabetes
diabetes = load_diabetes()
diabetes.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'DESCR', 'feature_names', 'data_filename', 'target_filename', 'data_module'])

# %%
diabetes['data'].shape
# Out:
# (442, 10)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(diabetes['data'], diabetes['target'], test_size=0.2, random_state=42)

from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([  37.90402135, -241.96436231,  542.42875852,  347.70384391,
#        -931.48884588,  518.06227698,  163.41998299,  275.31790158,
#         736.1988589 ,   48.67065743])

# %%
model.intercept_
# Out:
# np.float64(151.34560453985995)

# %%
model.singular_
# Out:
# array([1.7833465 , 1.08316955, 1.00102754, 0.89186601, 0.72039263,
#        0.69309186, 0.64643496, 0.58888127, 0.24563493, 0.08592908])

# %%
y_pred = model.predict(X_test)
y_pred.shape
# Out:
# (89,)

# %%
print(X_test[:,1].shape)
# Out:
# (89,)

# %%
model.score(X_test,y_test)
# Out:
# 0.4526027629719196

# %%
import matplotlib.pyplot as plt
plt.scatter(X_test[:,0],y_test)
plt.plot(X_test[:,0],model.predict(X_test),color="red",ls="-")
